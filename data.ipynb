# %%
import pandas as pd

df = pd.read_excel('Your_Path_File')

print(df.shape)

df
# Out:
# (2024, 13)
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 0     female      2006              2014   123.0    28.8     -0.50     0.50
# 1     female      2006              2014   133.0    37.9      0.12     0.62
# 2       male      2006              2014   119.5    21.4     -0.25    -0.50
# 3       male      2006              2014   122.5    23.5      0.25     0.00
# 4     female      2006              2014   128.0    27.7     -0.12    -0.25
# ...      ...       ...               ...     ...     ...       ...      ...
# 2019  female      2008              2017   124.0    27.5      0.00     0.25
# 2020    male      2008              2017   132.5    27.6      0.50     0.00
# 2021    male      2008              2017   129.5    25.2      1.25     0.75
# 2022  female      2008              2017   136.0    35.3      0.75     3.50
# 2023    male      2008              2017   132.0    26.0     -0.75     0.50
#
# ...

# %% [markdown]
# # **Collect average spherical refraction and axial length of myopic children from each year**
# 1.   Collect the data of children whose spherical refraction(SR) < 0 from each year
# 2.   Calculate the average for SR and axial length from each year
# ---

# %% [markdown]
# # **Collecting SR_right from 2014**

# %%
df[df.examination_date == 2014]
thnA = df[df.examination_date == 2014]

thnA
# Out:
#      gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 0    female      2006              2014   123.0    28.8     -0.50     0.50
# 1    female      2006              2014   133.0    37.9      0.12     0.62
# 2      male      2006              2014   119.5    21.4     -0.25    -0.50
# 3      male      2006              2014   122.5    23.5      0.25     0.00
# 4    female      2006              2014   128.0    27.7     -0.12    -0.25
# ..      ...       ...               ...     ...     ...       ...      ...
# 508  female      2008              2014   121.0    24.3      0.00     0.00
# 509  female      2007              2014   127.0    27.9      0.62     0.87
# 510    male      2008              2014   117.5    23.0     -0.12    -0.25
# 511  female      2006              2014   129.5    29.0      0.50     0.50
# 512    male      2007              2014   126.5    31.5      0.50     1.00
#
#     CR_right CR_left axis_right axis_left AL_right AL_left
# ...

# %%
thnA = df[df.examination_date == 2014]
thnA[thnA['SR_right'] < 0]
# Out:
#      gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 0    female      2006              2014   123.0    28.8     -0.50     0.50
# 2      male      2006              2014   119.5    21.4     -0.25    -0.50
# 4    female      2006              2014   128.0    27.7     -0.12    -0.25
# 5    female      2006              2014   135.5    35.5     -0.12     0.25
# 6      male      2006              2014   130.0    26.5     -1.50    -1.00
# ..      ...       ...               ...     ...     ...       ...      ...
# 484    male      2008              2014   115.0    21.9     -0.12    -0.12
# 500    male      2008              2014   112.0    19.1     -0.25     0.00
# 503  female      2007              2014   129.0    40.9     -0.50    -0.75
# 505  female      2007              2014   124.5    25.4     -0.25    -0.62
# 510    male      2008              2014   117.5    23.0     -0.12    -0.25
#
#     CR_right CR_left axis_right axis_left AL_right AL_left
# ...

# %%
meanAR = thnA[thnA['SR_right'] < 0]

print(meanAR.SR_right.mean())

meanAR
# Out:
# -0.638013698630137
#      gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 0    female      2006              2014   123.0    28.8     -0.50     0.50
# 2      male      2006              2014   119.5    21.4     -0.25    -0.50
# 4    female      2006              2014   128.0    27.7     -0.12    -0.25
# 5    female      2006              2014   135.5    35.5     -0.12     0.25
# 6      male      2006              2014   130.0    26.5     -1.50    -1.00
# ..      ...       ...               ...     ...     ...       ...      ...
# 484    male      2008              2014   115.0    21.9     -0.12    -0.12
# 500    male      2008              2014   112.0    19.1     -0.25     0.00
# 503  female      2007              2014   129.0    40.9     -0.50    -0.75
# 505  female      2007              2014   124.5    25.4     -0.25    -0.62
# 510    male      2008              2014   117.5    23.0     -0.12    -0.25
#
# ...

# %% [markdown]
# # **Average SR_right 2014**

# %%
ASRR14 = meanAR.SR_right.mean()
print (ASRR14)
# Out:
# -0.638013698630137

# %% [markdown]
# # **SR_left 2014**

# %%
meanAL = thnA[thnA['SR_left'] < 0]

print (meanAL.SR_left.mean())

meanAL
# Out:
# -0.563
#      gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 2      male      2006              2014   119.5    21.4     -0.25    -0.50
# 4    female      2006              2014   128.0    27.7     -0.12    -0.25
# 6      male      2006              2014   130.0    26.5     -1.50    -1.00
# 10     male      2006              2014   126.0    26.2     -0.25    -0.12
# 12     male      2006              2014   127.5    31.0      0.00    -0.12
# ..      ...       ...               ...     ...     ...       ...      ...
# 484    male      2008              2014   115.0    21.9     -0.12    -0.12
# 488  female      2008              2014   114.5    20.6      0.00    -0.12
# 503  female      2007              2014   129.0    40.9     -0.50    -0.75
# 505  female      2007              2014   124.5    25.4     -0.25    -0.62
# 510    male      2008              2014   117.5    23.0     -0.12    -0.25
#
#     CR_right CR_left axis_right axis_left AL_right AL_left
# ...

# %% [markdown]
# # **Average SR_left 2014**

# %%
ASRL14 = meanAL.SR_left.mean()
print (ASRL14)
# Out:
# -0.563

# %% [markdown]
# # **Collecting SR_right from 2015**

# %%
thnB = df[df.examination_date == 2015]
thnB
# Out:
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 513   female      2006              2015   129.0    30.2     -0.89    -0.38
# 514     male      2006              2015   130.0    26.0     -0.32    -0.21
# 515   female      2006              2015   136.0    30.8     -0.06    -0.98
# 516     male      2006              2015   136.5    30.4     -2.34    -1.87
# 517     male      2006              2015   137.0    46.3     -1.50    -1.75
# ...      ...       ...               ...     ...     ...       ...      ...
# 1009  female      2008              2015   123.2    22.6     -0.23     0.60
# 1010  female      2008              2015   118.0    18.3     -0.09    -0.81
# 1011  female      2008              2015   124.3    25.7      1.00     0.75
# 1012  female      2008              2015   123.6    22.5     -0.50    -0.25
# 1013    male      2008              2015   122.3    24.8     -0.42    -0.52
#
# ...

# %%
meanBR = thnB[thnB['SR_right'] < 0]
print(meanBR.SR_right.mean())
meanBR
# Out:
# -0.8851648351648352
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 513   female      2006              2015   129.0    30.2     -0.89    -0.38
# 514     male      2006              2015   130.0    26.0     -0.32    -0.21
# 515   female      2006              2015   136.0    30.8     -0.06    -0.98
# 516     male      2006              2015   136.5    30.4     -2.34    -1.87
# 517     male      2006              2015   137.0    46.3     -1.50    -1.75
# ...      ...       ...               ...     ...     ...       ...      ...
# 1006  female      2008              2015   130.5    27.8     -2.25    -2.00
# 1009  female      2008              2015   123.2    22.6     -0.23     0.60
# 1010  female      2008              2015   118.0    18.3     -0.09    -0.81
# 1012  female      2008              2015   123.6    22.5     -0.50    -0.25
# 1013    male      2008              2015   122.3    24.8     -0.42    -0.52
#
# ...

# %% [markdown]
# # **Average SR_right 2015**

# %%
ASRR15 = meanBR.SR_right.mean()
print (ASRR15)
# Out:
# -0.8851648351648352

# %% [markdown]
# # **SR_left 2015**

# %%
meanBL = thnB[thnB['SR_left'] < 0]

print (meanBL.SR_left.mean())

meanBL
# Out:
# -0.8048170731707318
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 513   female      2006              2015   129.0    30.2     -0.89    -0.38
# 514     male      2006              2015   130.0    26.0     -0.32    -0.21
# 515   female      2006              2015   136.0    30.8     -0.06    -0.98
# 516     male      2006              2015   136.5    30.4     -2.34    -1.87
# 517     male      2006              2015   137.0    46.3     -1.50    -1.75
# ...      ...       ...               ...     ...     ...       ...      ...
# 1005  female      2008              2015   135.0    31.8     -1.00    -0.50
# 1006  female      2008              2015   130.5    27.8     -2.25    -2.00
# 1010  female      2008              2015   118.0    18.3     -0.09    -0.81
# 1012  female      2008              2015   123.6    22.5     -0.50    -0.25
# 1013    male      2008              2015   122.3    24.8     -0.42    -0.52
#
# ...

# %% [markdown]
# # **Average SR_left 2015**

# %%
ASRL15 = meanBL.SR_left.mean()
print(ASRL15)
# Out:
# -0.8048170731707318

# %% [markdown]
# # **Collecting SR_right from 2016**

# %%
thnC = df[df.examination_date == 2016]
thnC
# Out:
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1014  female      2006              2016   144.5    37.5      0.00    -0.75
# 1015    male      2006              2016   142.0    35.3     -3.25    -3.00
# 1016  female      2006              2016   144.0    38.2      0.50     0.75
# 1017    male      2006              2016   142.3    41.0     -2.50    -2.75
# 1018  female      2006              2016   144.5    36.5      0.00     0.00
# ...      ...       ...               ...     ...     ...       ...      ...
# 1512    male      2007              2016   142.0    38.2     -0.50    -0.25
# 1513    male      2007              2016   134.0    34.7      0.50     0.25
# 1514  female      2007              2016   129.5    25.0     -0.50    -0.25
# 1515  female      2007              2016   138.5    31.0      0.00    -0.50
# 1516  female      2007              2016   144.5    50.0     -0.75     0.00
#
# ...

# %%
meanCR = thnC[thnC['SR_right'] < 0]
print(meanCR.SR_right.mean())
meanCR
# Out:
# -1.2592105263157896
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1015    male      2006              2016   142.0    35.3     -3.25    -3.00
# 1017    male      2006              2016   142.3    41.0     -2.50    -2.75
# 1020  female      2006              2016   130.0    31.5     -1.00     0.25
# 1021  female      2006              2016   139.0    31.0     -1.25    -1.25
# 1022  female      2006              2016   141.5    29.2     -2.25    -1.25
# ...      ...       ...               ...     ...     ...       ...      ...
# 1507  female      2007              2016   141.0    38.0     -2.25    -2.25
# 1510  female      2007              2016   136.0    25.9     -1.00    -1.00
# 1512    male      2007              2016   142.0    38.2     -0.50    -0.25
# 1514  female      2007              2016   129.5    25.0     -0.50    -0.25
# 1516  female      2007              2016   144.5    50.0     -0.75     0.00
#
# ...

# %% [markdown]
# # **Average SR_right 2016**

# %%
ASRR16 = meanCR.SR_right.mean()
print(ASRR16)
# Out:
# -1.2592105263157896

# %% [markdown]
# # **SR_left 2016**

# %%
meanCL = thnC[thnC['SR_left'] < 0]

print (meanCL.SR_left.mean())

meanCL
# Out:
# -1.1497093023255813
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1014  female      2006              2016   144.5    37.5      0.00    -0.75
# 1015    male      2006              2016   142.0    35.3     -3.25    -3.00
# 1017    male      2006              2016   142.3    41.0     -2.50    -2.75
# 1021  female      2006              2016   139.0    31.0     -1.25    -1.25
# 1022  female      2006              2016   141.5    29.2     -2.25    -1.25
# ...      ...       ...               ...     ...     ...       ...      ...
# 1507  female      2007              2016   141.0    38.0     -2.25    -2.25
# 1510  female      2007              2016   136.0    25.9     -1.00    -1.00
# 1512    male      2007              2016   142.0    38.2     -0.50    -0.25
# 1514  female      2007              2016   129.5    25.0     -0.50    -0.25
# 1515  female      2007              2016   138.5    31.0      0.00    -0.50
#
# ...

# %% [markdown]
# # **Average SR_left 2016**

# %%
ASRL16 = meanCL.SR_left.mean()
print(ASRL16)
# Out:
# -1.1497093023255813

# %% [markdown]
# # **Collecting SR_right from 2017**

# %%
thnD = df[df.examination_date == 2017]
thnD
# Out:
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1517  female      2006              2017   141.5    42.2     -1.75    -1.25
# 1518    male      2006              2017   138.0    31.3      0.00     0.50
# 1519    male      2006              2017   139.0    31.0     -2.00    -1.50
# 1520  female      2006              2017   152.5    46.2     -1.25    -1.25
# 1521  female      2006              2017   158.0    66.4     -0.50    -0.75
# ...      ...       ...               ...     ...     ...       ...      ...
# 2019  female      2008              2017   124.0    27.5      0.00     0.25
# 2020    male      2008              2017   132.5    27.6      0.50     0.00
# 2021    male      2008              2017   129.5    25.2      1.25     0.75
# 2022  female      2008              2017   136.0    35.3      0.75     3.50
# 2023    male      2008              2017   132.0    26.0     -0.75     0.50
#
# ...

# %%
meanDR = thnD[thnD['SR_right'] < 0]
print(meanDR.SR_right.mean())
meanDR
# Out:
# -1.639795918367347
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1517  female      2006              2017   141.5    42.2     -1.75    -1.25
# 1519    male      2006              2017   139.0    31.0     -2.00    -1.50
# 1520  female      2006              2017   152.5    46.2     -1.25    -1.25
# 1521  female      2006              2017   158.0    66.4     -0.50    -0.75
# 1522    male      2006              2017   147.0    35.6     -4.25    -4.00
# ...      ...       ...               ...     ...     ...       ...      ...
# 2013  female      2008              2017   134.0    28.8     -1.25     0.25
# 2014    male      2008              2017   144.0    45.4     -3.25    -2.50
# 2015  female      2008              2017   132.5    28.7     -0.25     0.00
# 2016    male      2008              2017   132.5    28.2     -1.00    -0.75
# 2023    male      2008              2017   132.0    26.0     -0.75     0.50
#
# ...

# %% [markdown]
# # **Average SR_right 2017**

# %%
ASRR17 = meanDR.SR_right.mean()
print(ASRR17)
# Out:
# -1.639795918367347

# %% [markdown]
# # **SR_left 2017**

# %%
meanDL = thnD[thnD['SR_left'] < 0]

print (meanDL.SR_left.mean())

meanDL
# Out:
# -1.5796943231441047
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1517  female      2006              2017   141.5    42.2     -1.75    -1.25
# 1519    male      2006              2017   139.0    31.0     -2.00    -1.50
# 1520  female      2006              2017   152.5    46.2     -1.25    -1.25
# 1521  female      2006              2017   158.0    66.4     -0.50    -0.75
# 1522    male      2006              2017   147.0    35.6     -4.25    -4.00
# ...      ...       ...               ...     ...     ...       ...      ...
# 2008    male      2008              2017   130.0    32.9      0.00    -0.25
# 2010  female      2008              2017   139.5    34.1      0.00    -1.00
# 2014    male      2008              2017   144.0    45.4     -3.25    -2.50
# 2016    male      2008              2017   132.5    28.2     -1.00    -0.75
# 2018  female      2008              2017   127.0    29.5      1.00    -0.25
#
# ...

# %% [markdown]
# # **Average SR_left 2017**

# %%
ASRL17 = meanDL.SR_left.mean()
print(ASRL17)
# Out:
# -1.5796943231441047

# %% [markdown]
# # **Average Axial Length 2014 - 2017**

# %% [markdown]
# ### **2014**

# %%
print("Right Eye: ")
ALR14 = meanAR.AL_right.mean()
print(ALR14)
print("Left Eye: ")
ALL14 = meanAL.AL_left.mean()
print(ALL14)

meanAR
# Out:
# Right Eye:
# 22.897397260273973
# Left Eye:
# 22.954545454545453
#      gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 0    female      2006              2014   123.0    28.8     -0.50     0.50
# 2      male      2006              2014   119.5    21.4     -0.25    -0.50
# 4    female      2006              2014   128.0    27.7     -0.12    -0.25
# 5    female      2006              2014   135.5    35.5     -0.12     0.25
# 6      male      2006              2014   130.0    26.5     -1.50    -1.00
# ..      ...       ...               ...     ...     ...       ...      ...
# 484    male      2008              2014   115.0    21.9     -0.12    -0.12
# 500    male      2008              2014   112.0    19.1     -0.25     0.00
# 503  female      2007              2014   129.0    40.9     -0.50    -0.75
# 505  female      2007              2014   124.5    25.4     -0.25    -0.62
# 510    male      2008              2014   117.5    23.0     -0.12    -0.25
#
# ...

# %% [markdown]
# ### **2015**

# %%
meanBR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
meanBL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')
# Out:
# <ipython-input-24-71aff463a063>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanBR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
# <ipython-input-24-71aff463a063>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanBL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')

# %%
print("Right Eye: ")
ALR15 = meanBR.AL_right.mean()
print(ALR15)

print("Left Eye: ")
ALL15 = meanBL.AL_left.mean()
print(ALL15)

meanBR
# Out:
# Right Eye:
# 23.40213333333333
# Left Eye:
# 23.29175182481752
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 513   female      2006              2015   129.0    30.2     -0.89    -0.38
# 514     male      2006              2015   130.0    26.0     -0.32    -0.21
# 515   female      2006              2015   136.0    30.8     -0.06    -0.98
# 516     male      2006              2015   136.5    30.4     -2.34    -1.87
# 517     male      2006              2015   137.0    46.3     -1.50    -1.75
# ...      ...       ...               ...     ...     ...       ...      ...
# 1006  female      2008              2015   130.5    27.8     -2.25    -2.00
# 1009  female      2008              2015   123.2    22.6     -0.23     0.60
# 1010  female      2008              2015   118.0    18.3     -0.09    -0.81
# 1012  female      2008              2015   123.6    22.5     -0.50    -0.25
# ...

# %%
meanBR.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right            float64
# AL_left              object
# dtype: object

# %%
meanBL.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right             object
# AL_left             float64
# dtype: object

# %% [markdown]
# ### **2016**

# %%
meanCR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
meanCL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')
# Out:
# <ipython-input-28-fa231ee628a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanCR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
# <ipython-input-28-fa231ee628a7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanCL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')

# %%
print("Right Eye: ")
ALR16 = meanCR.AL_right.mean()
print(ALR16)

print("Left Eye: ")
ALL16 = meanCL.AL_left.mean()
print(ALL16)

meanCR
# Out:
# Right Eye:
# 23.61777777777778
# Left Eye:
# 23.68473684210526
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1015    male      2006              2016   142.0    35.3     -3.25    -3.00
# 1017    male      2006              2016   142.3    41.0     -2.50    -2.75
# 1020  female      2006              2016   130.0    31.5     -1.00     0.25
# 1021  female      2006              2016   139.0    31.0     -1.25    -1.25
# 1022  female      2006              2016   141.5    29.2     -2.25    -1.25
# ...      ...       ...               ...     ...     ...       ...      ...
# 1507  female      2007              2016   141.0    38.0     -2.25    -2.25
# 1510  female      2007              2016   136.0    25.9     -1.00    -1.00
# 1512    male      2007              2016   142.0    38.2     -0.50    -0.25
# 1514  female      2007              2016   129.5    25.0     -0.50    -0.25
# ...

# %%
meanCR.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right            float64
# AL_left              object
# dtype: object

# %%
meanCL.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right             object
# AL_left             float64
# dtype: object

# %% [markdown]
# ### **2017**

# %%
meanDR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
meanDL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')
# Out:
# <ipython-input-32-475cf1757ae6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanDR['AL_right'] = pd.to_numeric(df['AL_right'],errors='coerce')
# <ipython-input-32-475cf1757ae6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanDL['AL_left'] = pd.to_numeric(df['AL_left'],errors='coerce')

# %%
print("Right Eye: ")
ALR17 = meanDR.AL_right.mean()
print(ALR17)

print("Left Eye: ")
ALL17 = meanDL.AL_left.mean()

print(ALL17)

meanDR
# Out:
# Right Eye:
# 24.001639344262298
# Left Eye:
# 23.97614035087719
#       gender  birthday  examination_date  height  weight  SR_right  SR_left  \
# 1517  female      2006              2017   141.5    42.2     -1.75    -1.25
# 1519    male      2006              2017   139.0    31.0     -2.00    -1.50
# 1520  female      2006              2017   152.5    46.2     -1.25    -1.25
# 1521  female      2006              2017   158.0    66.4     -0.50    -0.75
# 1522    male      2006              2017   147.0    35.6     -4.25    -4.00
# ...      ...       ...               ...     ...     ...       ...      ...
# 2013  female      2008              2017   134.0    28.8     -1.25     0.25
# 2014    male      2008              2017   144.0    45.4     -3.25    -2.50
# 2015  female      2008              2017   132.5    28.7     -0.25     0.00
# 2016    male      2008              2017   132.5    28.2     -1.00    -0.75
# ...

# %%
meanDR.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right            float64
# AL_left              object
# dtype: object

# %%
meanDL.dtypes
# Out:
# gender               object
# birthday              int64
# examination_date      int64
# height              float64
# weight              float64
# SR_right            float64
# SR_left             float64
# CR_right             object
# CR_left              object
# axis_right           object
# axis_left            object
# AL_right             object
# AL_left             float64
# dtype: object

# %% [markdown]
# # **Graph for myopia**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
## Line for Right Eye
x = [2014, 2015, 2016, 2017]
y = [ASRR14,ASRR15,ASRR16,ASRR17]

plt.plot(x,y, label = 'Right Eye', color='red', marker='.')
plt.title("Average Myopia Degree 2014 - 2017")
plt.xlabel("Year", fontdict={'fontsize': 10,}, fontweight="bold")
plt.ylabel("Diopters (D)", fontdict={'fontsize': 10}, fontweight="bold")

## Line for Left Eye
x2 = [2014,2015,2016,2017]
y2 = [ASRL14,ASRL15,ASRL16,ASRL17]

plt.plot(x2,y2, label = 'Left Eye', color= 'blue', marker='.')

plt.xticks([2014,2015,2016,2017])
plt.yticks([-0.56,-0.8,-0.88,-1.14,-1.25,-1.57,-1.63])

## To invert the yaxis
plt.gca().invert_yaxis()

plt.legend()

plt.show()

# To save the graph
#plt.savefig('/content/drive/MyDrive/mataData/myopia_graph.png', dpi=200, bbox_inches = 'tight')

# %% [markdown]
# # **Graph for Axial Length**

# %%
## Line for Right Eye
x = [2014, 2015, 2016, 2017]
y = [ALR14,ALR15,ALR16,ALR17]

plt.plot(x,y, label = 'Right Eye', color='red', marker='.')
plt.title("Average Axial Length 2014 - 2017")
plt.xlabel("Year", fontdict={'fontsize': 10,}, fontweight="bold")
plt.ylabel("Millimeter (mm)", fontdict={'fontsize': 10}, fontweight="bold")

## Line for Left Eye
x2 = [2014,2015,2016,2017]
y2 = [ALL14,ALL15,ALL16,ALL17]

plt.plot(x2,y2, label = 'Left Eye', color= 'blue', marker='.')

plt.xticks([2014,2015,2016,2017])
plt.yticks([22.89,22.95,23.29,23.4,23.61,23.68,24])

plt.legend()

plt.show()

## To save the graph
#plt.savefig('/content/drive/MyDrive/mataData/axial_length_graph.png', dpi=200, bbox_inches = 'tight')
